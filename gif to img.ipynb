# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from PIL import Image
import io
import csv
import os

def scrape_and_convert_gifs(url, csv_writer, save_folder):
    base_url = "https://tenor.com"
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, "html.parser")
        img_tags = soup.find_all("img")

        for img in img_tags:
            gif_url = img.get("src")
            alt_text = img.get("alt", "No description")
            if gif_url and gif_url.endswith(".gif"):  # Process only `.gif` files
                if not gif_url.startswith("http"):
                    gif_url = urljoin(base_url, gif_url)

                print(f"Processing: {gif_url}")
                # Convert .gif to .jpeg and save to the folder
                jpeg_file_path = convert_gif_to_jpeg(gif_url, save_folder)
                if jpeg_file_path:
                    # Write the .gif URL, .jpeg file path, and alt text to the CSV
                    csv_writer.writerow([gif_url, os.path.abspath(jpeg_file_path), alt_text])
    else:
        print(f"Failed to fetch {url}. Status code: {response.status_code}")

def convert_gif_to_jpeg(gif_url, save_folder):
    try:
        response = requests.get(gif_url, stream=True)
        if response.status_code == 200:
            gif_image = Image.open(io.BytesIO(response.content))  # Load GIF into memory
            jpeg_image = gif_image.convert("RGB")  # Convert to RGB for .jpeg format

            # Generate .jpeg file name
            gif_name = gif_url.split("/")[-1]
            jpeg_name = gif_name.replace(".gif", ".jpeg")

            # Save the .jpeg in the specified folder
            jpeg_file_path = os.path.join(save_folder, jpeg_name)
            jpeg_image.save(jpeg_file_path, "JPEG")
            print(f"Saved JPEG: {jpeg_file_path}")
            return jpeg_file_path
        else:
            print(f"Failed to download GIF: {gif_url}")
            return None
    except Exception as e:
        print(f"Error converting GIF: {e}")
        return None

# Main script
urls = [
    "https://tenor.com/en-IN/search/sunil-memes-gifs",
    # Add more URLs as needed...
]

# Specify the folder to save JPEG files
save_folder = input("Enter the full path of the folder to save JPEG files: ").strip()

# Ensure the specified folder exists
os.makedirs(save_folder, exist_ok=True)

# Path to the CSV file
csv_file = os.path.join(save_folder, "gif_to_jpeg_links.csv")

try:
    with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
        csv_writer = csv.writer(file)
        csv_writer.writerow(["Original GIF URL", "Converted JPEG File Path", "Image Alt Text"])  # Header

        for url in urls:
            print(f"\nScraping images from: {url}")
            scrape_and_convert_gifs(url, csv_writer, save_folder)
            print("\n" + "-" * 100 + "\n")

    print(f"Data has been written to {csv_file}")
except Exception as e:
    print(f"An error occurred while writing to CSV: {e}")
# Out:
# Enter the full path of the folder to save JPEG files:  test1
# Scraping images from: https://tenor.com/en-IN/search/sunil-memes-gifs
# Processing: https://media.tenor.com/_a6iQf-mhIwAAAAM/sunil-sontham.gif
# Saved JPEG: test1\sunil-sontham.jpeg
# Processing: https://media.tenor.com/JMGSNl_NPZEAAAAM/papam-feel-ayinattu-unnadu.gif
# Saved JPEG: test1\papam-feel-ayinattu-unnadu.jpeg
# Processing: https://media.tenor.com/-j1bIVeF-zsAAAAM/telugu-gifs.gif
# Saved JPEG: test1\telugu-gifs.jpeg
# Processing: https://media.tenor.com/CvA4r4voLkwAAAAM/sunil.gif
# Saved JPEG: test1\sunil.jpeg
# Processing: https://media.tenor.com/vzC7WgnH1sIAAAAM/sunil-telugu-andharivadu-comedy-chala-worst-ga-janaala-talk.gif
# Saved JPEG: test1\sunil-telugu-andharivadu-comedy-chala-worst-ga-janaala-talk.jpeg
# Processing: https://media.tenor.com/HLeUlh7FKkIAAAAM/sunil-comedy.gif
# Saved JPEG: test1\sunil-comedy.jpeg
# Processing: https://media.tenor.com/-M8uk72qHmMAAAAM/introverts-to-modi-speech-sunil.gif
# Saved JPEG: test1\introverts-to-modi-speech-sunil.jpeg
# Processing: https://media.tenor.com/AvMlsrt7u14AAAAM/chusthunnaa-anni-observe-chesthunna-sunil.gif
# Saved JPEG: test1\chusthunnaa-anni-observe-chesthunna-sunil.jpeg
# Processing: https://tenor.com/assets/img/gif-maker-entrypoints/search-entrypoint-optimized.gif
# Saved JPEG: test1\search-entrypoint-optimized.jpeg
# Processing: https://media.tenor.com/cwMeOifysFEAAAAM/sunil.gif
# Saved JPEG: test1\sunil.jpeg
# Processing: https://media.tenor.com/RL203EIlC5gAAAAM/sunil-reactions.gif
# Saved JPEG: test1\sunil-reactions.jpeg
# Processing: https://media.tenor.com/mKZG6WMYf8EAAAAM/sunil-funny-expression-sunil.gif
# Saved JPEG: test1\sunil-funny-expression-sunil.jpeg
# Processing: https://media.tenor.com/UdbjczQ5NzoAAAAM/35.gif
# Saved JPEG: test1\35.jpeg
# Processing: https://media.tenor.com/wtzq-5zeUEQAAAAM/kurrathanam-poled-ehe-sunil.gif
# Saved JPEG: test1\kurrathanam-poled-ehe-sunil.jpeg
# Processing: https://media.tenor.com/3vwWWu3vgOMAAAAM/sayamkalam-sunil.gif
# Saved JPEG: test1\sayamkalam-sunil.jpeg
# Processing: https://media.tenor.com/P6hrdthKkEwAAAAM/sontham-sunil.gif
# Saved JPEG: test1\sontham-sunil.jpeg
# Processing: https://media.tenor.com/tq6jT7_dA3gAAAAM/sontham-telugu.gif
# Saved JPEG: test1\sontham-telugu.jpeg
# Processing: https://media.tenor.com/xihWdn_aEbsAAAAM/sandeepkvk18.gif
# Saved JPEG: test1\sandeepkvk18.jpeg
# Processing: https://media.tenor.com/_70-nfJhsNsAAAAM/sunil-fy.gif
# Saved JPEG: test1\sunil-fy.jpeg
# Processing: https://media.tenor.com/azvCl-GkWIQAAAAM/sunil-comedy.gif
# Saved JPEG: test1\sunil-comedy.jpeg
# Processing: https://media.tenor.com/-h2lsJHXMpwAAAAM/thokkathotakura-ttk.gif
# Saved JPEG: test1\thokkathotakura-ttk.jpeg
# Processing: https://media.tenor.com/5cBEHwe-c98AAAAM/pakkelli-aadukoma-prabhas.gif
# Saved JPEG: test1\pakkelli-aadukoma-prabhas.jpeg
# Processing: https://media.tenor.com/U-R01wCvDcgAAAAM/ha-ha-ha.gif
# Saved JPEG: test1\ha-ha-ha.jpeg
# Processing: https://media.tenor.com/oRDxbm1ORFgAAAAM/angry-sunil.gif
# Saved JPEG: test1\angry-sunil.jpeg
# Processing: https://media.tenor.com/rYy8BMad-2MAAAAM/sunil.gif
# Saved JPEG: test1\sunil.jpeg
# Processing: https://media.tenor.com/29Y_MLHG-KsAAAAM/sunil.gif
# Saved JPEG: test1\sunil.jpeg
# Processing: https://media.tenor.com/c4AbvI2KymoAAAAM/yem-cheppavuraa-sunil.gif
# Saved JPEG: test1\yem-cheppavuraa-sunil.jpeg
# Processing: https://media.tenor.com/Xs6LYfb4JvsAAAAM/manduthunnattu-vundhi-sunil.gif
# Saved JPEG: test1\manduthunnattu-vundhi-sunil.jpeg
# Processing: https://media.tenor.com/6otiSwqOOrsAAAAM/very-reasonable-sunil.gif
# Saved JPEG: test1\very-reasonable-sunil.jpeg
# Processing: https://media.tenor.com/bc2eTzVMFgwAAAAM/nidra-nuvvu-naaku-nachav.gif
# Saved JPEG: test1\nidra-nuvvu-naaku-nachav.jpeg
# Processing: https://media.tenor.com/6RgwAAMa6MIAAAAM/nuvvostanante-nenodhantana.gif
# Saved JPEG: test1\nuvvostanante-nenodhantana.jpeg
# Processing: https://media.tenor.com/sCou6lhxy1cAAAAM/sunil.gif
# Saved JPEG: test1\sunil.jpeg
# Processing: https://media.tenor.com/LbN7-1cSW0sAAAAM/kaun-kaun-hai-re-tu.gif
# Saved JPEG: test1\kaun-kaun-hai-re-tu.jpeg
# Processing: https://media.tenor.com/yV2FwrbzOjQAAAAM/svskittu-shivapanchadi.gif
# Saved JPEG: test1\svskittu-shivapanchadi.jpeg
# Processing: https://media.tenor.com/cWJ-ekJApJUAAAAj/abbe-akkarledamma-sticker.gif
# Saved JPEG: test1\abbe-akkarledamma-sticker.jpeg
# Processing: https://media.tenor.com/0cK4h2aF6SkAAAAM/telugu-funny.gif
# Saved JPEG: test1\telugu-funny.jpeg
# Processing: https://media.tenor.com/SQkjuuj2X_YAAAAM/aaha-abbo.gif
# Saved JPEG: test1\aaha-abbo.jpeg
# Processing: https://media.tenor.com/cimCMIhfXQ8AAAAM/vellu-pakkaki-vellu-sunil.gif
# Saved JPEG: test1\vellu-pakkaki-vellu-sunil.jpeg
# Processing: https://media.tenor.com/wl3J3aBCxmEAAAAM/sunil-sontham.gif
# Saved JPEG: test1\sunil-sontham.jpeg
# Processing: https://media.tenor.com/XKPa1N6O1cAAAAAM/chandramohan-udaykiran.gif
# Saved JPEG: test1\chandramohan-udaykiran.jpeg
# Processing: https://media.tenor.com/J87fNej9dMcAAAAM/mangalam-srinu-to-minister-sunil.gif
# Saved JPEG: test1\mangalam-srinu-to-minister-sunil.jpeg
# Processing: https://media.tenor.com/9HBmVqkyzfsAAAAM/antha-happy-happy.gif
# Saved JPEG: test1\antha-happy-happy.jpeg
# Processing: https://media.tenor.com/BR24fp287KsAAAAM/sunil-emotional.gif
# Saved JPEG: test1\sunil-emotional.jpeg
# Processing: https://media.tenor.com/qXOqvDC37jUAAAAM/yaa-yes.gif
# Saved JPEG: test1\yaa-yes.jpeg
# Processing: https://media.tenor.com/V2JGJ3rJjo4AAAAM/mangalam-srinu-pushpa.gif
# Saved JPEG: test1\mangalam-srinu-pushpa.jpeg
# Processing: https://media.tenor.com/E6XphgM6dCgAAAAM/buddhi-vundha-ledha-neeku-sunil.gif
# Saved JPEG: test1\buddhi-vundha-ledha-neeku-sunil.jpeg
# Processing: https://media.tenor.com/4hINClR-vmoAAAAM/sontham-sunil.gif
# Saved JPEG: test1\sontham-sunil.jpeg
# Processing: https://media.tenor.com/mZ6WTlnFFoYAAAAM/sontham-telugu.gif
# Saved JPEG: test1\sontham-telugu.jpeg
# Processing: https://media.tenor.com/fczFXiFLkuAAAAAM/telugu-funny-memes-mariendukuraneeku.gif
# Saved JPEG: test1\telugu-funny-memes-mariendukuraneeku.jpeg
# Processing: https://media.tenor.com/dZueV_k-MWsAAAAM/crying-sad-face.gif
# Saved JPEG: test1\crying-sad-face.jpeg
#
# ----------------------------------------------------------------------------------------------------
#
# Data has been written to test1\gif_to_jpeg_links.csv
